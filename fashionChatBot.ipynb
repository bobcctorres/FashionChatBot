# %% [markdown]
# # Custom Chatbot Project

# %% [markdown]
# The datasets choosen to compose the knowledge base for this Chatbot include the CSV Fashion Trends for 2023 and a Wikipedia on Red Carpet Fashion for celebrities. The idea is creating a personal stylist (or a first step towards it)!

# %% [markdown]
# ## Data Wrangling
#
# TODO: In the cells below, load your chosen dataset into a `pandas` dataframe with a column named `"text"`. This column should contain all of your text data, separated into at least 20 rows.

# %%
## Using Wikipedia Red Carpet Data

# %%
from dateutil.parser import parse
import pandas as pd
import requests

# Get the Wikipedia page for "2023"
resp = requests.get("https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&titles=Red_carpet_fashion&explaintext=1&formatversion=2&format=json")

# Load page text into a dataframe
df1 = pd.DataFrame()
df1["text"] = resp.json()["query"]["pages"][0]["extract"].split("\n")

# Clean up text to remove empty lines and headings
df1 = df1[(df1["text"].str.len() > 0) & (~df1["text"].str.startswith("=="))]

# In some cases dates are used as headings instead of being part of the
# text sample; adjust so dated text samples start with dates
prefix = ""
for (i, row) in df1.iterrows():
    # If the row already has " - ", it already has the needed date prefix
    if " – " not in row["text"]:
        try:
            # If the row's text is a date, set it as the new prefix
            parse(row["text"])
            prefix = row["text"]
        except:
            # If the row's text isn't a date, add the prefix
            row["text"] = prefix + " – " + row["text"]
df1 = df1[df1["text"].str.contains(" – ")]
df1
# Out:
#                                                  text
# 0    – Red carpet fashion consists of outfits worn...
# 4    – Prior to the 1990s, many celebrities chose ...
# 8    – Having a dress featured on the red carpet, ...
# 10   – "The dollar return of having some celebrity...
# 12   – "I can't possibly quantify how much publici...
# 16   – Fashion commentary often forms a key part o...
# 20   – When the 65th Golden Globe Awards ceremony ...
# 24                       – List of individual dresses

# %%
# Checking on the other Provided CSV datasets

# %%
def load_local_dataset(filename):
    df = pd.read_csv(filename, index_col=0)
    return df

# %%
df2 = load_local_dataset("./data/2023_fashion_trends.csv")
df2
# Out:
#                                                                                                Trends  \
# URL
# https://www.refinery29.com/en-us/fashion-trends...  2023 Fashion Trend: Red. Glossy red hues took ...
# https://www.refinery29.com/en-us/fashion-trends...  2023 Fashion Trend: Cargo Pants. Utilitarian w...
# https://www.refinery29.com/en-us/fashion-trends...  2023 Fashion Trend: Sheer Clothing. "Bare it a...
# https://www.refinery29.com/en-us/fashion-trends...  2023 Fashion Trend: Denim Reimagined. From dou...
# https://www.refinery29.com/en-us/fashion-trends...  2023 Fashion Trend: Shine For The Daytime. The...
# ...                                                                                               ...
# https://www.whowhatwear.com/spring-summer-2023-...  If lime green isn't your vibe, rest assured th...
# https://www.whowhatwear.com/spring-summer-2023-...  "As someone who can clearly (not fondly) remem...
# https://www.whowhatwear.com/spring-summer-2023-...  "Combine this design shift with the fact that ...
# https://www.whowhatwear.com/spring-summer-2023-...  Thought party season ended at the stroke of mi...
# https://www.whowhatwear.com/spring-summer-2023-...  "This season, we saw the revival of the bubble...
#
#                                                                                                Source
# URL
# https://www.refinery29.com/en-us/fashion-trends...  7 Fashion Trends That Will Take Over 2023 — Sh...
# https://www.refinery29.com/en-us/fashion-trends...  7 Fashion Trends That Will Take Over 2023 — Sh...
# https://www.refinery29.com/en-us/fashion-trends...  7 Fashion Trends That Will Take Over 2023 — Sh...
# https://www.refinery29.com/en-us/fashion-trends...  7 Fashion Trends That Will Take Over 2023 — Sh...
# https://www.refinery29.com/en-us/fashion-trends...  7 Fashion Trends That Will Take Over 2023 — Sh...
# ...                                                                                               ...
# https://www.whowhatwear.com/spring-summer-2023-...  Spring/Summer 2023 Fashion Trends: 21 Expert-A...
# https://www.whowhatwear.com/spring-summer-2023-...  Spring/Summer 2023 Fashion Trends: 21 Expert-A...
# https://www.whowhatwear.com/spring-summer-2023-...  Spring/Summer 2023 Fashion Trends: 21 Expert-A...
# https://www.whowhatwear.com/spring-summer-2023-...  Spring/Summer 2023 Fashion Trends: 21 Expert-A...
# https://www.whowhatwear.com/spring-summer-2023-...  Spring/Summer 2023 Fashion Trends: 21 Expert-A...
#
# [82 rows x 2 columns]

# %%
df3 = load_local_dataset("./data/character_descriptions.csv")
df3
# Out:
#                                                             Description  \
# Name
# Emily                 A young woman in her early 20s, Emily is an as...
# Jack                  A middle-aged man in his 40s, Jack is a succes...
# Alice                 A woman in her late 30s, Alice is a warm and n...
# Tom                   A man in his 50s, Tom is a retired soldier and...
# Sarah                 A woman in her mid-20s, Sarah is a free-spirit...
# George                A man in his early 30s, George is a charming a...
# Rachel                A woman in her late 20s, Rachel is a shy and i...
# John                  A man in his 60s, John is a retired professor ...
# Maria                 A middle-aged Latina woman in her 40s, Maria i...
# Caleb                 A young African American man in his early 20s,...
# Tyler                 A white man in his mid-30s, Tyler is a tough-a...
# Sonya                 A white woman in her late 20s, Sonya is a free...
# Manuel                A middle-aged Hispanic man in his 50s, Manuel ...
# Will                  A white man in his early 40s, Will is a succes...
# Mia                   A young Australian woman in her mid-20s, Mia i...
# Lucas                 A middle-aged Australian man in his 40s, Lucas...
# Tahlia                A young Indigenous Australian woman in her ear...
# Max                   A white Australian man in his late 20s, Max is...
# Ava                   A middle-aged Australian woman in her 50s, Ava...
# Donna                 A seasoned performer with a larger-than-life p...
# Johnny                A young up-and-coming performer, Johnny is ful...
# Sable                 A sultry and dramatic performer, Sable exudes ...
# Dolly                 A bubbly and vivacious performer, Dolly is a f...
# Vixen                 A fierce and competitive performer, Vixen is a...
# Karma                 A chameleon-like performer, Karma is known for...
# Crystal               A quirky and imaginative performer, Crystal is...
# Olivia                A confident and charismatic marketing executiv...
# Marcus                A charming and successful entrepreneur, Marcus...
# Maya                  A kind and compassionate nurse with a heart of...
# James                 A handsome and athletic personal trainer, Jame...
# Sophia                A fun-loving and adventurous travel blogger, S...
# Noah                  A quirky and creative graphic designer, Noah i...
# Chloe                 A driven and ambitious attorney, Chloe is alwa...
# Jake                  A laid-back and easygoing firefighter, Jake is...
# Prince Lorenzo        A charming and handsome prince who has recentl...
# Signora Rosa          A mysterious and alluring woman who runs a loc...
# Baron Gustavo         A wealthy and arrogant nobleman who loves to f...
# Francesca             A fiery and passionate young woman who works a...
# Don Carlo             A charming and charismatic young man who is of...
# Duke Orsino           A pompous and self-important nobleman who is h...
# Lady Olivia           A wealthy and beautiful noblewoman who has rec...
# Sir Toby Belch        A drunken and lecherous knight who loves nothi...
# Malvolio              A pompous and self-righteous steward in Lady O...
# Viola                 A plucky and resourceful young woman who is sh...
# Sir Andrew Aguecheek  A dim-witted and gullible nobleman who is brou...
# Bianca                Lady Olivia's cunning and quick-witted maid. B...
# Sebastian             Viola's twin brother, who is also shipwrecked ...
# Feste                 A jester and musician who works in Lady Olivia...
# Antonio               A sea captain who rescues Sebastian from the s...
# Abigail               A plucky and resourceful young woman who works...
# Thomas                A good-natured and affable young man who also ...
# Reverend Brown        The pious and stern minister of the local chur...
# Captain James         The charismatic and dashing captain of the loc...
# Mrs. Mercer           The matriarch of the wealthiest family in Will...
# Mr. Mercer            The bumbling and absent-minded patriarch of th...
#
#                               Medium         Setting
# Name
# Emily                           Play         England
# Jack                            Play         England
# Alice                           Play         England
# Tom                             Play         England
# Sarah                           Play         England
# George                          Play         England
# Rachel                          Play         England
# John                            Play         England
# Maria                          Movie           Texas
# Caleb                          Movie           Texas
# Tyler                          Movie           Texas
# Sonya                          Movie           Texas
# Manuel                         Movie           Texas
# Will                           Movie           Texas
# Mia                   Limited Series       Australia
# Lucas                 Limited Series       Australia
# Tahlia                Limited Series       Australia
# Max                   Limited Series       Australia
# Ava                   Limited Series       Australia
# Donna                        Musical             USA
# Johnny                       Musical             USA
# Sable                        Musical             USA
# Dolly                        Musical             USA
# Vixen                        Musical             USA
# Karma                        Musical             USA
# Crystal                      Musical             USA
# Olivia                  Reality Show             USA
# Marcus                  Reality Show             USA
# Maya                    Reality Show             USA
# James                   Reality Show             USA
# Sophia                  Reality Show             USA
# Noah                    Reality Show             USA
# Chloe                   Reality Show             USA
# Jake                    Reality Show             USA
# Prince Lorenzo                 Opera           Italy
# Signora Rosa                   Opera           Italy
# Baron Gustavo                  Opera           Italy
# Francesca                      Opera           Italy
# Don Carlo                      Opera           Italy
# Duke Orsino                     Play  Ancient Greece
# Lady Olivia                     Play  Ancient Greece
# Sir Toby Belch                  Play  Ancient Greece
# Malvolio                        Play  Ancient Greece
# Viola                           Play  Ancient Greece
# Sir Andrew Aguecheek            Play  Ancient Greece
# Bianca                          Play  Ancient Greece
# Sebastian                       Play  Ancient Greece
# Feste                           Play  Ancient Greece
# Antonio                         Play  Ancient Greece
# Abigail                       Sitcom             USA
# Thomas                        Sitcom             USA
# Reverend Brown                Sitcom             USA
# Captain James                 Sitcom             USA
# Mrs. Mercer                   Sitcom             USA
# Mr. Mercer                    Sitcom             USA

# %%
df4 = load_local_dataset("./data/nyc_food_scrap_drop_off_sites.csv")
df4
# Out:
#            borough                                     ntaname  \
# 0    Staten Island  Grasmere-Arrochar-South Beach-Dongan Hills
# 1        Manhattan                                      Inwood
# 2         Brooklyn                                  Park Slope
# 3        Manhattan                         East Harlem (North)
# 4           Queens                                      Corona
# ..             ...                                         ...
# 571       Brooklyn                                  Kensington
# 572         Queens                   Old Astoria-Hallets Point
# 573       Brooklyn                       Crown Heights (North)
# 574       Brooklyn                 Windsor Terrace-South Slope
# 575          Bronx   University Heights (South)-Morris Heights
#
#                               food_scrap_drop_off_site  \
# 0                                          South Beach
# 1               SE Corner of Broadway & Academy Street
# 2                             Old Stone House Brooklyn
# 3          SE Corner of Pleasant Avenue & E 116 Street
# 4                                       Malcolm X FSDO
# ..                                                 ...
# 571                 Albemarle Road and McDonald Avenue
# 572              NW Corner of 21st Street & 30th Drive
# 573                 Rochester Avenue & St. Johns Place
# 574  *CLOSED FOR THE SEASON* East 4th Street Commun...
# 575                    Community Access - Davidson Ave
#
#                                               location  \
# 0                      21 Robin Road, Staten Island NY
# 1                                                  NaN
# 2                       336 3rd St, Brooklyn, NY 11215
# 3                                                  NaN
# 4             111-26 Northern Blvd, Flushing, NY 11368
# ..                                                 ...
# 571  southwest corner of McDonald Avenue and Albema...
# 572                                                NaN
# 573                                                NaN
# 574                   173 E 4th St, Brooklyn, NY 11218
# 575                                  1750 Davidson Ave
#
#                                             hosted_by      open_months  \
# 0                                   Snug Harbor Youth       Year Round
# 1                            Department of Sanitation       Year Round
# 2                            Old Stone House Brooklyn       Year Round
# 3                            Department of Sanitation       Year Round
# 4             NYC Compost Project Hosted by Big Reuse       Year Round
# ..                                                ...              ...
# 571  NYC Compost Project Hosted by LES Ecology Center       Year Round
# 572                          Department of Sanitation       Year Round
# 573                          Department of Sanitation       Year Round
# 574       Members at East 4th Street Community Garden  April - October
# 575                                           GrowNYC       Year Round
#
#                                    operation_day_hours  \
# 0    Friday (Start Time: 1:30 PM - End Time:  4:30 PM)
# 1                                                 24/7
# 2            24/7 (Start Time: 24/7 - End Time:  24/7)
# 3                                                 24/7
# 4    Tuesdays (Start Time: 12:00 PM - End Time:  2:...
# ..                                                 ...
# 571  Tuesdays (Start Time: 10:00 AM - End Time:  2:...
# 572                                               24/7
# 573                                               24/7
# 574  Wednesdays and Saturdays (Start Time: Wednesda...
# 575  Thursdays (Start Time: 8:30 AM - End Time:  1:...
#
#                                                website  borocd  councildist  \
# 0                                      snug-harbor.org     502           50
# 1                          www.nyc.gov/smartcomposting     112           10
# 2                                                  NaN     306           39
# 3                          www.nyc.gov/smartcomposting     111            8
# 4                                                  NaN     404           21
# ..                                                 ...     ...          ...
# 571  https://www.lesecologycenter.org/programs/comp...     312           39
# 572                        www.nyc.gov/smartcomposting     401           22
# 573                        www.nyc.gov/smartcomposting     308           41
# 574         https://eastfourthstreetgarden.tumblr.com/     307           39
# 575                           www.communityaccess.org/     205           14
#
#      ...                                     location_point  \
# 0    ...  {'type': 'Point', 'coordinates': [-74.062991, ...
# 1    ...                                                NaN
# 2    ...  {'type': 'Point', 'coordinates': [-73.984731, ...
# 3    ...                                                NaN
# 4    ...  {'type': 'Point', 'coordinates': [-73.8630721,...
# ..   ...                                                ...
# 571  ...  {'type': 'Point', 'coordinates': [-73.97997, 4...
# 572  ...                                                NaN
# 573  ...                                                NaN
# 574  ...  {'type': 'Point', 'coordinates': [-73.9772287,...
# 575  ...  {'type': 'Point', 'coordinates': [-73.913085, ...
#
#      :@computed_region_yeji_bk3q  :@computed_region_92fq_4b7q  \
# 0                            1.0                         14.0
# 1                            NaN                          NaN
# 2                            2.0                         27.0
# 3                            NaN                          NaN
# 4                            3.0                         21.0
# ..                           ...                          ...
# 571                          2.0                         27.0
# 572                          NaN                          NaN
# 573                          NaN                          NaN
# 574                          2.0                         27.0
# 575                          5.0                         29.0
#
#      :@computed_region_sbqj_enih :@computed_region_efsh_h5xi  \
# 0                           76.0                     10692.0
# 1                            NaN                         NaN
# 2                           50.0                     17617.0
# 3                            NaN                         NaN
# 4                           68.0                     14510.0
# ..                           ...                         ...
# 571                         39.0                     17620.0
# 572                          NaN                         NaN
# 573                          NaN                         NaN
# 574                         45.0                     17620.0
# 575                         29.0                     10931.0
#
#      :@computed_region_f5dn_yrer  \
# 0                           30.0
# 1                            NaN
# 2                           14.0
# 3                            NaN
# 4                           66.0
# ..                           ...
# 571                          2.0
# 572                          NaN
# 573                          NaN
# 574                          9.0
# 575                          6.0
#
#                                                  notes  ct2010           bbl  \
# 0                                                  NaN     NaN           NaN
# 1    Download the app to access bins. Accepts all f...     NaN           NaN
# 2                                                  NaN     NaN           NaN
# 3    Download the app to access bins. Accepts all f...     NaN           NaN
# 4                                                  NaN     NaN           NaN
# ..                                                 ...     ...           ...
# 571                Not accepted: meat, bones, or dairy     NaN           NaN
# 572  Download the app to access bins. Accepts all f...     NaN           NaN
# 573  Download the app to access bins. Accepts all f...     NaN           NaN
# 574                Not accepted: meat, bones, or dairy     NaN           NaN
# 575                Not accepted: meat, bones, or dairy   217.0  2.028610e+09
#
#            bin
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 571        NaN
# 572        NaN
# 573        NaN
# 574        NaN
# 575  2115886.0
#
# [576 rows x 24 columns]

# %%
# Final composed dataset will use the Wikipedia dataset with the Fashion Trends CSV
# The other two CSV files won´t be useful for this task

# %%
df = pd.DataFrame(df1["text"].tolist() + df2["Trends"].tolist(), columns=['text'])
df
# Out:
#                                                  text
# 0    – Red carpet fashion consists of outfits worn...
# 1    – Prior to the 1990s, many celebrities chose ...
# 2    – Having a dress featured on the red carpet, ...
# 3    – "The dollar return of having some celebrity...
# 4    – "I can't possibly quantify how much publici...
# ..                                                ...
# 85  If lime green isn't your vibe, rest assured th...
# 86  "As someone who can clearly (not fondly) remem...
# 87  "Combine this design shift with the fact that ...
# 88  Thought party season ended at the stroke of mi...
# 89  "This season, we saw the revival of the bubble...
#
# [90 rows x 1 columns]

# %% [markdown]
# ## Custom Query Completion
#
# TODO: In the cells below, compose a custom query using your chosen dataset and retrieve results from an OpenAI `Completion` model. You may copy and paste any useful code from the course materials.

# %%
import openai
openai.api_key = "YOUR API KEY"

# %%
# Generating Embeddings
# We'll use the Embedding tooling from OpenAI documentation here to create vectors representing each row of our custom dataset.
# In order to avoid a RateLimitError we'll send our data in batches to the Embedding.create function.

# %%
EMBEDDING_MODEL_NAME = "text-embedding-ada-002"
batch_size = 100
embeddings = []
for i in range(0, len(df), batch_size):
    # Send text data to OpenAI model to get embeddings
    response = openai.Embedding.create(
        input=df.iloc[i:i+batch_size]["text"].tolist(),
        engine=EMBEDDING_MODEL_NAME
    )
    
    # Add embeddings to list
    embeddings.extend([data["embedding"] for data in response["data"]])

# Add embeddings list to dataframe
df["embeddings"] = embeddings
df
# Out:
#                                                  text  \
# 0    – Red carpet fashion consists of outfits worn...
# 1    – Prior to the 1990s, many celebrities chose ...
# 2    – Having a dress featured on the red carpet, ...
# 3    – "The dollar return of having some celebrity...
# 4    – "I can't possibly quantify how much publici...
# ..                                                ...
# 85  If lime green isn't your vibe, rest assured th...
# 86  "As someone who can clearly (not fondly) remem...
# 87  "Combine this design shift with the fact that ...
# 88  Thought party season ended at the stroke of mi...
# 89  "This season, we saw the revival of the bubble...
#
#                                            embeddings
# 0   [0.005555762909352779, -0.014635973609983921, ...
# 1   [0.0023636522237211466, -0.028377050533890724,...
# 2   [-0.0323331244289875, -0.015973027795553207, 0...
# 3   [-0.018000848591327667, -0.003702789079397917,...
# 4   [-0.004414374940097332, -0.011313684284687042,...
# ..                                                ...
# 85  [-0.0027722418308258057, -0.018304530531167984...
# 86  [-0.014718359336256981, -0.006478246301412582,...
# 87  [-0.020781872794032097, -0.025097381323575974,...
# 88  [-0.019844094291329384, -0.022332968190312386,...
# 89  [-0.031002795323729515, 0.0019995153415948153,...
#
# [90 rows x 2 columns]

# %%
# In order to avoid having to run that code again in the future, we'll save the generated embeddings as a CSV file.

df.to_csv("embeddings.csv")

# %%
# What we are implementing here is similar to a search engine or recommendation algorithm. We want to sort all of the rows of our dataset from least relevant to most relevant.
#This will use the embeddings that we generated previously in order to compare the vectorized version of our question to the vectorized versions of the rows of the dataset.

# %%
from openai.embeddings_utils import get_embedding, distances_from_embeddings

def get_rows_sorted_by_relevance(question, df):
    """
    Function that takes in a question string and a dataframe containing
    rows of text and associated embeddings, and returns that dataframe
    sorted from least to most relevant for that question
    """
    
    # Get embeddings for the question text
    question_embeddings = get_embedding(question, engine=EMBEDDING_MODEL_NAME)
    
    # Make a copy of the dataframe and add a "distances" column containing
    # the cosine distances between each row's embeddings and the
    # embeddings of the question
    df_copy = df.copy()
    df_copy["distances"] = distances_from_embeddings(
        question_embeddings,
        df_copy["embeddings"].values,
        distance_metric="cosine"
    )
    
    # Sort the copied dataframe by the distances and return it
    # (shorter distance = more relevant so we sort in ascending order)
    df_copy.sort_values("distances", ascending=True, inplace=True)
    return df_copy

# %%
# Let's test that out for a couple different questions:
get_rows_sorted_by_relevance("What is a good trending dress?", df)
# Out:
#                                                  text  \
# 84  "If there's one dress update you consider for ...
# 41  Draped Dressing. I can’t wait to wear spring’s...
# 80  "Sheer fashion dominated the trends conversati...
# 11  2023 Fashion Trend: Denim Reimagined. From dou...
# 10  2023 Fashion Trend: Sheer Clothing. "Bare it a...
# ..                                                ...
# 34  Bright White Footwear. I'm excited to lighten ...
# 26  Oversized Bags. As cute as they can be, tiny b...
# 45  The-Bigger-the-Better Bags. Gone are the days ...
# 35  Sculptural Statement Earrings. For me, this sp...
# 6    – When the 65th Golden Globe Awards ceremony ...
#
#                                            embeddings  distances
# 84  [-0.036194704473018646, -0.028788169845938683,...   0.154156
# 41  [-0.015158192254602909, -0.004933060612529516,...   0.157154
# 80  [-0.012716786004602909, 0.001000983058474958, ...   0.162433
# 11  [-0.015580940060317516, -0.005439954809844494,...   0.167760
# 10  [-0.01045039389282465, -0.01925569400191307, 0...   0.169798
# ..                                                ...        ...
# 34  [0.0003186866524629295, -0.028604554012417793,...   0.234027
# 26  [-0.0016623392002657056, -0.006312215700745583...   0.236258
# 45  [-0.011331110261380672, -0.0035833714064210653...   0.240910
# 35  [-0.03322748839855194, -0.004589776508510113, ...   0.241846
# 6   [-0.006143881939351559, -0.02652035467326641, ...   0.242723
#
# [90 rows x 3 columns]

# %%
get_rows_sorted_by_relevance("What should I choose to wear in a Hollywood Oscar Awards?", df)
# Out:
#                                                  text  \
# 1    – Prior to the 1990s, many celebrities chose ...
# 0    – Red carpet fashion consists of outfits worn...
# 6    – When the 65th Golden Globe Awards ceremony ...
# 2    – Having a dress featured on the red carpet, ...
# 4    – "I can't possibly quantify how much publici...
# ..                                                ...
# 45  The-Bigger-the-Better Bags. Gone are the days ...
# 35  Sculptural Statement Earrings. For me, this sp...
# 13  2023 Fashion Trend: Maxi Skirts. In response t...
# 69  "As seen in Miu Miu's Milan Fashion Week show,...
# 26  Oversized Bags. As cute as they can be, tiny b...
#
#                                            embeddings  distances
# 1   [0.0023636522237211466, -0.028377050533890724,...   0.149775
# 0   [0.005555762909352779, -0.014635973609983921, ...   0.180514
# 6   [-0.006143881939351559, -0.02652035467326641, ...   0.189700
# 2   [-0.0323331244289875, -0.015973027795553207, 0...   0.193474
# 4   [-0.004414374940097332, -0.011313684284687042,...   0.194693
# ..                                                ...        ...
# 45  [-0.011331110261380672, -0.0035833714064210653...   0.264268
# 35  [-0.03322748839855194, -0.004589776508510113, ...   0.264694
# 13  [-0.02548186294734478, -0.019320974126458168, ...   0.269355
# 69  [-0.03086216375231743, -0.007000280544161797, ...   0.271559
# 26  [-0.0016623392002657056, -0.006312215700745583...   0.276368
#
# [90 rows x 3 columns]

# %%
# Use ChatGPT LLM to get final responses:

# %%
import tiktoken

def create_prompt(question, df, max_token_count):
    """
    Given a question and a dataframe containing rows of text and their
    embeddings, return a text prompt to send to a Completion model
    """
    # Create a tokenizer that is designed to align with our embeddings
    tokenizer = tiktoken.get_encoding("cl100k_base")
    
    # Count the number of tokens in the prompt template and question
    prompt_template = """
Answer the question based on the context below, and if the question
can't be answered based on the context, say "I don't know"

Context: 

{}

---

Question: {}
Answer:"""
    
    current_token_count = len(tokenizer.encode(prompt_template)) + \
                            len(tokenizer.encode(question))
    
    context = []
    for text in get_rows_sorted_by_relevance(question, df)["text"].values:
        
        # Increase the counter based on the number of tokens in this row
        text_token_count = len(tokenizer.encode(text))
        current_token_count += text_token_count
        
        # Add the row of text to the list if we haven't exceeded the max
        if current_token_count <= max_token_count:
            context.append(text)
        else:
            break

    return prompt_template.format("\n\n###\n\n".join(context), question)

# %%
print(create_prompt("What is a good trending dress?", df, 200))
# Out:
# Answer the question based on the context below, and if the question
# can't be answered based on the context, say "I don't know"
#
# Context:
#
#
#
# ---
#
# Question: What is a good trending dress?
# Answer:

# %%
# Our final step is to send that text prompt to a Completion model and parse the model output!

COMPLETION_MODEL_NAME = "gpt-3.5-turbo-instruct"

def answer_question(
    question, df, max_prompt_tokens=1800, max_answer_tokens=150
):
    """
    Given a question, a dataframe containing rows of text, and a maximum
    number of desired tokens in the prompt and response, return the
    answer to the question according to an OpenAI Completion model
    
    If the model produces an error, return an empty string
    """
    
    prompt = create_prompt(question, df, max_prompt_tokens)
    
    try:
        response = openai.Completion.create(
            model=COMPLETION_MODEL_NAME,
            prompt=prompt,
            max_tokens=max_answer_tokens
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %% [markdown]
# ## Custom Performance Demonstration
#
# TODO: In the cells below, demonstrate the performance of your custom query using at least 2 questions. For each question, show the answer from a basic `Completion` model query as well as the answer from your custom query.

# %%
question1_prompt = """
Question: "What is the trend fashion in 2023?"
Answer:
"""
initial_question1_answer = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=question1_prompt,
    max_tokens=150
)["choices"][0]["text"].strip()
print(initial_question1_answer)
# Out:
# It is difficult to predict specific fashion trends for 2023, as fashion is constantly evolving and changing. However, some experts predict that sustainable and eco-friendly fashion will continue to be a major trend as consumers become more conscious about their impact on the environment. Minimalism and gender-neutral styles may also gain popularity, as well as bold and vibrant colors and playful prints. Athleisure and streetwear are also expected to remain strong trends in 2023. Ultimately, fashion is a form of self-expression and personal style, so it is likely that there will be a mix of various trends in the fashion world in 2023.

# %%
question2_prompt = """
Question: "What should I choose as a male dressing to wear in a Hollywood Oscar Awards?"
Answer:
"""
initial_question2_answer = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=question2_prompt,
    max_tokens=150
)["choices"][0]["text"].strip()
print(initial_question2_answer)
# Out:
# As a male attending the Hollywood Oscar Awards, you should choose a formal and stylish outfit. Some options could include a sharp tuxedo with a classic black bowtie or a sleek, tailored suit in a bold color like navy blue or burgundy. Accessorize with a pocket square, polished dress shoes, and a statement watch. You could also consider a modern take on the traditional attire by opting for a fitted suit with a black shirt and no tie. Whichever outfit you choose, make sure it is well-fitted and reflects your personal style while being appropriate for a formal event like the Oscars.

# %% [markdown]
# ### Question 1

# %%
custom_question1_answer = answer_question("What is the trend fashion in 2023?", df)
print(custom_question1_answer)
# Out:
# Some of the trending fashion styles in 2023 include sheer clothing, red hues, shine for daytime, maximalist trends, cargo pants, elevated basics, denim reimagined, surrealism and 3D designs, maxi skirts, slouchy-fit trousers, green hues, perfectly cut trousers, pinstripe tailoring, and "indie sleaze" style.

# %%
print("Basic Completion Answer: " + initial_question1_answer)
# Out:
# Basic Completion Answer: It is difficult to predict specific fashion trends for 2023, as fashion is constantly evolving and changing. However, some experts predict that sustainable and eco-friendly fashion will continue to be a major trend as consumers become more conscious about their impact on the environment. Minimalism and gender-neutral styles may also gain popularity, as well as bold and vibrant colors and playful prints. Athleisure and streetwear are also expected to remain strong trends in 2023. Ultimately, fashion is a form of self-expression and personal style, so it is likely that there will be a mix of various trends in the fashion world in 2023.

# %% [markdown]
# ### Question 2

# %%
custom_question2_answer = answer_question("What should I choose as a male dressing to wear in a Hollywood Oscar Awards?", df)
print(custom_question2_answer)
# Out:
# The best option for a male dressing for the Hollywood Oscar Awards is to choose a tailored suit, preferably in a bold color such as red or lime green. This will help you stand out on the red carpet and make a fashionable statement.

# %%
print("Basic Completion Answer: " + initial_question2_answer)
# Out:
# Basic Completion Answer: As a male attending the Hollywood Oscar Awards, you should choose a formal and stylish outfit. Some options could include a sharp tuxedo with a classic black bowtie or a sleek, tailored suit in a bold color like navy blue or burgundy. Accessorize with a pocket square, polished dress shoes, and a statement watch. You could also consider a modern take on the traditional attire by opting for a fitted suit with a black shirt and no tie. Whichever outfit you choose, make sure it is well-fitted and reflects your personal style while being appropriate for a formal event like the Oscars.
